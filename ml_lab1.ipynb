# %% [markdown]
# <a href="https://colab.research.google.com/github/TanmayLimje/Machine-Learning/blob/main/ml_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/datasets/best-selling-manga.csv")

# %%
df
# Out:
#                       Manga series                      Author(s)  \
# 0                        One Piece                   Eiichiro Oda
# 1                         Golgo 13  Takao Saito, Saito Production
# 2    Case Closed / Detective Conan                   Gosho Aoyama
# 3                      Dragon Ball                 Akira Toriyama
# 4                         Doraemon                Fujiko F. Fujio
# ..                             ...                            ...
# 182                   Sukeban Deka                    Shinji Wada
# 183                           Swan                 Kyoko Ariyoshi
# 184              The Tale of Genji                    Waki Yamato
# 185       Tokyo Daigaku Monogatari                  Tatsuya Egawa
# 186                           Weed            Yoshihiro Takahashi
#
#            Publisher Demographic  No. of collected volumes    Serialized  \
# 0           Shueisha      Shōnen                       104  1997–present
# ...

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/datasets/backloggd_games.csv")

# %%
dataframe
# Out:
#        Unnamed: 0                                       Title  Release_Date  \
# 0               0                                  Elden Ring  Feb 25, 2022
# 1               1     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2               2                                       Hades  Dec 07, 2018
# 3               3                               Hollow Knight  Feb 24, 2017
# 4               4                                   Undertale  Sep 15, 2015
# ...           ...                                         ...           ...
# 59995       59995                              Dragon Spirits  Apr 25, 2023
# 59996       59996  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
# 59997       59997                                      Sainth  Apr 11, 2008
# 59998       59998                              Dragon Spirits  Apr 25, 2023
# 59999       59999  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
#
# ...

# %%
dataframe.isnull
# Out:
# <bound method DataFrame.isnull of        Unnamed: 0                                       Title  Release_Date  \
# 0               0                                  Elden Ring  Feb 25, 2022
# 1               1     The Legend of Zelda: Breath of the Wild  Mar 03, 2017
# 2               2                                       Hades  Dec 07, 2018
# 3               3                               Hollow Knight  Feb 24, 2017
# 4               4                                   Undertale  Sep 15, 2015
# ...           ...                                         ...           ...
# 59995       59995                              Dragon Spirits  Apr 25, 2023
# 59996       59996  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
# 59997       59997                                      Sainth  Apr 11, 2008
# 59998       59998                              Dragon Spirits  Apr 25, 2023
# 59999       59999  Pathfinder: Kingmaker - Definitive Edition  Aug 18, 2020
#
# ...

# %%
dataframe.mean()
# Out:
# <ipython-input-14-ad2b37d7ca22>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataframe.mean()
# Unnamed: 0    29999.500000
# Rating            3.033171
# dtype: float64

# %%
dataframe.count()
# Out:
# Unnamed: 0      60000
# Title           60000
# Release_Date    60000
# Developers      60000
# Summary         55046
# Platforms       60000
# Genres          60000
# Rating          25405
# Plays           60000
# Playing         60000
# Backlogs        60000
# Wishlist        60000
# Lists           60000
# Reviews         60000
# dtype: int64

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60000 non-null  int64
#  1   Title         60000 non-null  object
#  2   Release_Date  60000 non-null  object
#  3   Developers    60000 non-null  object
#  4   Summary       55046 non-null  object
#  5   Platforms     60000 non-null  object
#  6   Genres        60000 non-null  object
#  7   Rating        25405 non-null  float64
#  8   Plays         60000 non-null  object
#  9   Playing       60000 non-null  object
#  10  Backlogs      60000 non-null  object
#  11  Wishlist      60000 non-null  object
#  12  Lists         60000 non-null  object
#  13  Reviews       60000 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 6.4+ MB

# %%
dataframe.Rating.mean()
# Out:
# 3.0331706357016333

# %%
dataframe.describe()
# Out:
#          Unnamed: 0        Rating
# count  60000.000000  25405.000000
# mean   29999.500000      3.033171
# std    17320.652413      0.735573
# min        0.000000      0.300000
# 25%    14999.750000      2.600000
# 50%    29999.500000      3.100000
# 75%    44999.250000      3.500000
# max    59999.000000      5.000000

# %%
df.describe()
# Out:
#        No. of collected volumes  Approximate sales in million(s)  \
# count                187.000000                       187.000000
# mean                  46.048128                        50.764332
# std                   34.678288                        57.178028
# min                    5.000000                        20.000000
# 25%                   23.500000                        24.500000
# 50%                   34.000000                        31.000000
# 75%                   56.500000                        50.500000
# max                  207.000000                       516.600000
#
#        Average sales per volume in million(s)
# count                              187.000000
# mean                                 1.377380
# std                                  1.240013
# min                                  0.190000
# 25%                                  0.670000
# 50%                                  1.030000
# 75%                                  1.650000
# ...

# %%
df
# Out:
#                       Manga series                      Author(s)  \
# 0                        One Piece                   Eiichiro Oda
# 1                         Golgo 13  Takao Saito, Saito Production
# 2    Case Closed / Detective Conan                   Gosho Aoyama
# 3                      Dragon Ball                 Akira Toriyama
# 4                         Doraemon                Fujiko F. Fujio
# ..                             ...                            ...
# 182                   Sukeban Deka                    Shinji Wada
# 183                           Swan                 Kyoko Ariyoshi
# 184              The Tale of Genji                    Waki Yamato
# 185       Tokyo Daigaku Monogatari                  Tatsuya Egawa
# 186                           Weed            Yoshihiro Takahashi
#
#            Publisher Demographic  No. of collected volumes    Serialized  \
# 0           Shueisha      Shōnen                       104  1997–present
# ...

# %%
df.describe()
# Out:
#        No. of collected volumes  Approximate sales in million(s)  \
# count                187.000000                       187.000000
# mean                  46.048128                        50.764332
# std                   34.678288                        57.178028
# min                    5.000000                        20.000000
# 25%                   23.500000                        24.500000
# 50%                   34.000000                        31.000000
# 75%                   56.500000                        50.500000
# max                  207.000000                       516.600000
#
#        Average sales per volume in million(s)
# count                              187.000000
# mean                                 1.377380
# std                                  1.240013
# min                                  0.190000
# 25%                                  0.670000
# 50%                                  1.030000
# 75%                                  1.650000
# ...

# %%
selected_Att = df[["Manga series","No. of collected volumes"]]

# %%
selected_Att = selected_Att.rename(columns = {"Manga series" : "Name", "No. of collected volumes" : "vols"})

# %%
selected_Att.to_csv("new.csv")

# %%
df3 = pd.read_csv("new.csv")

# %%
df3
# Out:
#      Unnamed: 0                           Name  vols
# 0             0                      One Piece   104
# 1             1                       Golgo 13   207
# 2             2  Case Closed / Detective Conan   102
# 3             3                    Dragon Ball    42
# 4             4                       Doraemon    45
# ..          ...                            ...   ...
# 182         182                   Sukeban Deka    22
# 183         183                           Swan    21
# 184         184              The Tale of Genji    13
# 185         185       Tokyo Daigaku Monogatari    34
# 186         186                           Weed    60
#
# [187 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6065999874099456955 = autoviz.get_registered_df('df_6065999874099456955')
#
# ...

# %%
import math

# %%
from sklearn.model_selection import train_test_split

# %%
Publisher_train, Publiser_test = train_test_split(df.Publisher, random_state = 0, test_size = 0.75, shuffle = True)

# %%
Publisher_train.head()
# Out:
# 162           Shueisha
# 17          Shogakukan
# 38            Kodansha
# 133    Kadokawa Shoten
# 53          Hakusensha
# Name: Publisher, dtype: object

# %%
df
# Out:
#                       Manga series                      Author(s)  \
# 0                        One Piece                   Eiichiro Oda
# 1                         Golgo 13  Takao Saito, Saito Production
# 2    Case Closed / Detective Conan                   Gosho Aoyama
# 3                      Dragon Ball                 Akira Toriyama
# 4                         Doraemon                Fujiko F. Fujio
# ..                             ...                            ...
# 182                   Sukeban Deka                    Shinji Wada
# 183                           Swan                 Kyoko Ariyoshi
# 184              The Tale of Genji                    Waki Yamato
# 185       Tokyo Daigaku Monogatari                  Tatsuya Egawa
# 186                           Weed            Yoshihiro Takahashi
#
#            Publisher Demographic  No. of collected volumes    Serialized  \
# 0           Shueisha      Shōnen                       104  1997–present
# ...
